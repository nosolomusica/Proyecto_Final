# %%
# Cargar el archivo de audio
#y, sr = librosa.load(ruta_audio, sr=None)  # sr=None mantiene la tasa de muestreo original del audio

# Ahora puedes usar tu función extract_features
#caracteristicas = extract_features(y, sr)

# Ver las características extraídas
#print(caracteristicas)

# %%
import librosa
import pandas as pd

# %%
# Lista de rutas de los archivos MP3
rutas_audio = [
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Alice Deejay_Better Off Alone_Electronica_Dance_2000.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Calvin Harris y Ellie Goulding_Miracle_Electronica_Dance_2023.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/David Guetta y Anne_Baby Don’t Hurt Me_Electronica_Dance_2023.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Edward Maya & Vika Jigulina_Stereo Love_Electronica_Dance_2009.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Erika_I Don't Know_Electronica_Dance_2004.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Flo Rida_Club Can't Handle Me_Electronica_Dance_2010.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Gigi D'agostino_L'amour toujour_Electronica_Dance_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Lasgo_I Wonder_Electronica_Dance_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Lasgo_Something_Electronica_Dance_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Rimini Project_Sounds Good_Electronica_Dance_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Sash! feat Tina Cousins_Mysterious Times_Electronica_Dance_2012.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Snap!_Rhythm is a Dancer_Electronica_Dance_1992.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Sylver_Skin_Electronica_Dance_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Sylver_Skin_Electronica_Dance_2024.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Sylver_Turn the tide_Electronica_Dance_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Dance/Yolanda Be Cool & DCUP_We No Speak Americano_Electronica_Dance_2010.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Grauzone_Eisbaer_Rock_New Wave_1980.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Human Tetris_Things I don't need_Rock_New Wave_2010.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Las Eras_Virginia_Rock_New Wave_2024.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Lebanon Hanover_Gallowdance_Rock_New Wave_2013.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Linea Aspera_Malarone_Rock_New Wave_2012.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Pleasure Symbols_Control_Rock_New Wave_2016.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Psyche_Goodbye Horses_Rock_New Wave_1996.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Rue Oberkampf_Hope and Fear_Rock_New Wave_2022.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Sad lovers and Giants_Things we never did_Rock_New Wave_1982.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Ultra Sun_Distress_Rock_New Wave_2024.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Boy Harsher_Machina_Rock_New Wave_2022.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Caminatas Nocturnas_Morir es sólo despertar_2002.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Killing Joke_Love Like Blood _Rock_Dark Wave_1985.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/VVV Trippin You_Nunca Estuvimos Tan Lejos_Rock_New Wave_2019.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Silent EM_Wraith_ Rock_New Wave_2013.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Sixth June_Drowning_2013.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/VVV Trippin You_Amianto_Rock_New Wave_2021.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/VVV Trippin You_Invierno nuclear_Rock_New Wave_2020.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/VVV Trippin You_Lluvias de Marzo_Rock_New Wave_2021.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/VVV Trippin You_Matar el Tiempo_Rock_New Wave_2021.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/VVV Trippin You_Monstruo_Rock_New Wave_2021.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Zanias_Unraveled_Rock_New Wave_2021.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/New Wave/Zanias_Follow the Body_Rock_New Wave_2016.mp3"]

# %%
def extract_features(y, sr):
    tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
    beats = len(beat_frames)
    rmse = librosa.feature.rms(y=y)
    rmse_values = rmse[0][:20]  # Tomamos los primeros 20 valores de RMSE
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13).mean()
    zcr = librosa.feature.zero_crossing_rate(y).mean()
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr).mean()
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr).mean()
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr).mean()
    chroma = librosa.feature.chroma_stft(y=y, sr=sr).mean()


    return {
        "beats": beats,
        "tempo": tempo,
        "mfcc": mfcc.tolist(),
        "zero_crossing_rate": zcr,
        "rolloff": rolloff,
        "spectral_centroid": spectral_centroid,
        "spectral_bandwidth": spectral_bandwidth,
        "chroma_stft": chroma,
        "rmse_1": rmse_values[0] if len(rmse_values) > 0 else None,
        "rmse_2": rmse_values[1] if len(rmse_values) > 1 else None,
        "rmse_3": rmse_values[2] if len(rmse_values) > 2 else None,
        "rmse_4": rmse_values[3] if len(rmse_values) > 3 else None,
        "rmse_5": rmse_values[4] if len(rmse_values) > 4 else None,
        "rmse_6": rmse_values[5] if len(rmse_values) > 5 else None,
        "rmse_7": rmse_values[6] if len(rmse_values) > 6 else None,
        "rmse_8": rmse_values[7] if len(rmse_values) > 7 else None,
        "rmse_9": rmse_values[8] if len(rmse_values) > 8 else None,
        "rmse_10": rmse_values[9] if len(rmse_values) > 9 else None,
        "rmse_11": rmse_values[10] if len(rmse_values) > 10 else None,
        "rmse_12": rmse_values[11] if len(rmse_values) > 11 else None,
        "rmse_13": rmse_values[12] if len(rmse_values) > 12 else None,
        "rmse_14": rmse_values[13] if len(rmse_values) > 13 else None,
        "rmse_15": rmse_values[14] if len(rmse_values) > 14 else None,
        "rmse_16": rmse_values[15] if len(rmse_values) > 15 else None,
        "rmse_17": rmse_values[16] if len(rmse_values) > 16 else None,
        "rmse_18": rmse_values[17] if len(rmse_values) > 17 else None,
        "rmse_19": rmse_values[18] if len(rmse_values) > 18 else None,
        "rmse_20": rmse_values[19] if len(rmse_values) > 19 else None,    
        
    }

# Lista para almacenar los resultados
datos_audio = []

# Procesar cada archivo en la lista
for ruta in rutas_audio:
    try:
        y, sr = librosa.load(ruta, sr=None)  # Cargar archivo de audio
        caracteristicas = extract_features(y, sr)  # Extraer características
        caracteristicas["file"] = ruta  # Agregar el nombre del archivo
        datos_audio.append(caracteristicas)  # Guardar los resultados
    except Exception as e:
        print(f"Error procesando {ruta}: {e}")

# Crear un DataFrame con los datos
df_audio = pd.DataFrame(datos_audio)

# Mostrar el DataFrame
print(df_audio)

# Opcional: Guardar el DataFrame en un archivo CSV
df_audio.to_csv("caracteristicas_audio.csv", index=False)
# Out:
#     beats                 tempo       mfcc  zero_crossing_rate      rolloff  \
# 0     381  [135.99917763157896]   3.403080            0.101790  9249.568195
# 1     433         [143.5546875]   4.800573            0.061558  6829.635627
# 2     351        [129.19921875]   8.427510            0.059146  6718.444180
# 3     382  [126.04801829268293]   4.400158            0.070170  7335.060038
# 4     412        [129.19921875]   6.315407            0.039045  6101.478814
# 5     513        [129.19921875]   1.133823            0.089066  6996.504458
# 6     545   [139.6748310810811]   2.882359            0.055119  5473.059403
# 7     493   [139.6748310810811]   3.796379            0.058391  6551.428357
# 8     508   [139.6748310810811]   0.795086            0.060064  6489.133780
# 9     790   [139.6748310810811]   5.964798            0.085775  8245.387553
# 10    488  [135.99917763157896]  -2.789468            0.051843  6648.201313
# 11    470          [123.046875]   3.094694            0.061216  6237.987947
# 12    568   [139.6748310810811]   3.563621            0.067664  5629.475532
# 13    568   [139.6748310810811]   3.563621            0.067664  5629.475532
...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 32  9.571197e-02  ...  7.976981e-02  7.734361e-02  7.724198e-02  7.680973e-02
# 33  1.829607e-04  ...  2.298418e-01  2.171073e-01  2.199867e-01  2.124933e-01
# 34  4.396300e-01  ...  4.357816e-02  2.149089e-02  9.628480e-03  4.756187e-03
# 35  2.409304e-02  ...  3.897181e-02  3.590519e-02  3.099015e-02  2.559847e-02
# 36  1.189953e-07  ...  1.115407e-01  1.367189e-01  1.595328e-01  1.760658e-01
# 37  0.000000e+00  ...  1.614075e-05  1.669844e-05  1.643706e-05  1.710432e-05
# 38  0.000000e+00  ...  1.391537e-01  1.378260e-01  1.400529e-01  1.383816e-01
#
#      rmse_16   rmse_17   rmse_18   rmse_19   rmse_20  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.164806  0.212698  0.245858  0.261388  0.241509
# 2   0.000075  0.031874  0.132987  0.220642  0.300733
# 3   0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.007054  0.008526  0.010066  0.011933  0.013245
# 5   0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.001012  0.001075  0.001068  0.001111  0.000966
# 7   0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.001031  0.001054  0.001094  0.000928  0.001046
# 9   0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000282  0.000292  0.000341  0.000336  0.000319
# 11  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.001557  0.002083  0.002753  0.004027  0.005383
# 13  0.001557  0.002083  0.002753  0.004027  0.005383
# 14  0.000021  0.000017  0.000045  0.032929  0.059227
# 15  0.347776  0.350868  0.356859  0.366104  0.369717
# 16  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.145980  0.176834  0.145742  0.174804  0.177481
# 19  0.020591  0.019721  0.019877  0.021898  0.023094
# 20  0.000072  0.000081  0.000085  0.000085  0.000087
# 21  0.000003  0.000022  0.098985  0.130823  0.208632
# 22  0.000104  0.000105  0.000098  0.001021  0.003291
# 23  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.000000  0.000000
# 25  0.178712  0.167144  0.188271  0.167919  0.166028
# 26  0.000000  0.000000  0.000000  0.000000  0.000000
# 27  0.078778  0.078891  0.084928  0.092848  0.096164
# 28  0.000216  0.000209  0.000204  0.000208  0.000215
# 29  0.005122  0.005777  0.006401  0.006950  0.007551
# 30  0.030003  0.031302  0.034053  0.035211  0.036107
# 31  0.000000  0.000000  0.000000  0.000000  0.000000
# 32  0.079482  0.087391  0.093146  0.097402  0.098628
# 33  0.205594  0.197491  0.185533  0.178980  0.174358
# 34  0.002741  0.001319  0.000559  0.001123  0.196904
# 35  0.020956  0.016353  0.013838  0.017637  0.018278
# 36  0.174772  0.188718  0.198146  0.197878  0.209389
# 37  0.000017  0.000018  0.000019  0.000022  0.000021
# 38  0.146229  0.153027  0.155231  0.157056  0.149847
#
#                                                  file
# 0   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 1   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 2   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 3   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 4   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 5   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 6   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 7   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 8   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 9   /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 10  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 11  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 12  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 13  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 14  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 15  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 16  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 17  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 18  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 19  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 20  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 21  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 22  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 23  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 24  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 25  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 26  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 27  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 28  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 29  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 30  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 31  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 32  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 33  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 34  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 35  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 36  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 37  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 38  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
#
# [39 rows x 29 columns]

# %%
df_audio= pd.read_csv("caracteristicas_audio.csv")

# %%
df_audio

# %%
datos_canciones = []

# Procesar cada archivo en la lista
for ruta in rutas_audio:
    # Obtener solo el nombre del archivo
    archivo = ruta.split('/')[-1]
    # Separar el nombre del archivo en partes (artista, canción, género, subgénero y año)
    partes = archivo.split('_')
    if len(partes) >= 5:  # Asegurarse de que hay al menos tres partes
        artist = partes[0].replace('-', ' ')  # Reemplazar guiones por espacios
        song = partes[1].replace('-', ' ')
        genre = partes[2].replace('-', ' ')  # Quitar la extensión
        subgenre = partes[3].replace('-', ' ')
        year = partes[4].replace('-', ' ').replace('.mp3', '')
        # Añadir los datos como diccionario a la lista
        datos_canciones.append({
            "artist": artist,
            "song": song,
            "genre": genre,
            "subgenre": subgenre,
            "year": year
        })

# Crear un DataFrame con los datos
df_canciones = pd.DataFrame(datos_canciones)

# Mostrar el DataFrame
print(df_canciones)

# Opcional: Guardar el DataFrame en un archivo CSV
df_canciones.to_csv("datos_canciones.csv", index=False)
# Out:
#                             artist                       song        genre  \
# 0                     Alice Deejay           Better Off Alone  Electronica
# 1   Calvin Harris y Ellie Goulding                    Miracle  Electronica
# 2              David Guetta y Anne         Baby Don’t Hurt Me  Electronica
# 3      Edward Maya & Vika Jigulina                Stereo Love  Electronica
# 4                            Erika               I Don't Know  Electronica
# 5                         Flo Rida       Club Can't Handle Me  Electronica
# 6                  Gigi D'agostino            L'amour toujour  Electronica
# 7                            Lasgo                   I Wonder  Electronica
# 8                            Lasgo                  Something  Electronica
# 9                   Rimini Project                Sounds Good  Electronica
# 10         Sash! feat Tina Cousins           Mysterious Times  Electronica
# 11                           Snap!         Rhythm is a Dancer  Electronica
# 12                          Sylver                       Skin  Electronica
# 13                          Sylver                       Skin  Electronica
# 14                          Sylver              Turn the tide  Electronica
# 15          Yolanda Be Cool & DCUP      We No Speak Americano  Electronica
# 16                        Grauzone                    Eisbaer         Rock
# 17                    Human Tetris        Things I don't need         Rock
# 18                        Las Eras                   Virginia         Rock
# 19                 Lebanon Hanover                Gallowdance         Rock
# 20                    Linea Aspera                   Malarone         Rock
# 21                Pleasure Symbols                    Control         Rock
# 22                          Psyche             Goodbye Horses         Rock
# 23                   Rue Oberkampf              Hope and Fear         Rock
# 24           Sad lovers and Giants        Things we never did         Rock
# 25                       Ultra Sun                   Distress         Rock
# 26                     Boy Harsher                    Machina         Rock
# 27                    Killing Joke           Love Like Blood          Rock
# 28                 VVV Trippin You  Nunca Estuvimos Tan Lejos         Rock
# 29                       Silent EM                     Wraith         Rock
# 30                 VVV Trippin You                    Amianto         Rock
# 31                 VVV Trippin You           Invierno nuclear         Rock
# 32                 VVV Trippin You           Lluvias de Marzo         Rock
# 33                 VVV Trippin You            Matar el Tiempo         Rock
# 34                 VVV Trippin You                   Monstruo         Rock
# 35                          Zanias                  Unraveled         Rock
# 36                          Zanias            Follow the Body         Rock
#
#      subgenre  year
# 0       Dance  2000
# 1       Dance  2023
# 2       Dance  2023
# 3       Dance  2009
# 4       Dance  2004
# 5       Dance  2010
# 6       Dance  2001
# 7       Dance  2001
# 8       Dance  2001
# 9       Dance  2001
# 10      Dance  2012
# 11      Dance  1992
# 12      Dance  2001
# 13      Dance  2024
# 14      Dance  2001
# 15      Dance  2010
# 16   New Wave  1980
# 17   New Wave  2010
# 18   New Wave  2024
# 19   New Wave  2013
# 20   New Wave  2012
# 21   New Wave  2016
# 22   New Wave  1996
# 23   New Wave  2022
# 24   New Wave  1982
# 25   New Wave  2024
# 26   New Wave  2022
# 27  Dark Wave  1985
# 28   New Wave  2019
# 29   New Wave  2013
# 30   New Wave  2021
# 31   New Wave  2020
# 32   New Wave  2021
# 33   New Wave  2021
# 34   New Wave  2021
# 35   New Wave  2021
# 36   New Wave  2016

# %%
df_canciones = pd.read_csv("datos_canciones.csv")

# %%
df_canciones

# %%
df = pd.merge(df_canciones, df_audio, left_index=True, right_index=True, how='inner')

# %%
df.to_csv('musica1.csv', index=False)

# %%
df= pd.read_csv('musica1.csv')

# %%
columnas_a_formatear = ['rmse_1', 'rmse_2', 'rmse_3', 'rmse_4', 'rmse_5','rmse_6', 'rmse_7', 'rmse_8', 'rmse_9', 'rmse_10', 'rmse_11', 'rmse_12', 'rmse_13', 'rmse_14', 'rmse_15', 
                        'rmse_16', 'rmse_17', 'rmse_18', 'rmse_19', 'rmse_20']

# Verifica si las columnas existen en el DataFrame
columnas_presentes = [col for col in columnas_a_formatear if col in df.columns]

# Aplicar formato con dos decimales
df[columnas_presentes] = df[columnas_presentes].applymap(lambda x: f"{x:.8f}")

# Guardar el archivo con los valores formateados
df.to_csv('archivo_formateado.csv', index=False)
# Out:
# /var/folders/cz/35gfl8ts1n39c5cfv2rn7pxw0000gn/T/ipykernel_24569/3537738360.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[columnas_presentes] = df[columnas_presentes].applymap(lambda x: f"{x:.8f}")

# %%
df= pd.read_csv('archivo_formateado.csv')

# %%
rutas_audio2 = ["/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Abel Ramos_Das spiegel_Electronica_Remember_1999.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Allegro_Moments In Love_Electronica_Remember_1999.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Aquagen_Everybody Is Free_Electronica_Remember_2004.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Butcher_Don't let the Sun go down_Electronica_Remember_2003.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/C Base _In The Beginning_Electronica_Remember_2003.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Dave 202_Baracuda_Electronica_Remember_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/David_Max Apology_Electronica_Remember_2000.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Dj Crivi_Mankell (Gaupasa Version)_Electronica_Remember_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Dj Rai_A Hidde Place_Electronica_Remember_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Dj Liberty_Seguro_Electronica_Remember_2004.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Jesus Elices_Maximizing the Audience_Electronica_Remember_2001.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Espada y Vidar_Sienteme_Electronica_Remember_2004.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Remember/Fiocco_Afflitto_Electronica_Remember_1997.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/4 Non Blondes_What's Up_Rock_Rock Baladas_1993.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Aerosmith_Amazing_Rock_Rock Baladas_1993.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Aerosmith_I Don't Want to Miss a Thing_Rock_Rock Baladas_1998.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Air Supply_Making Love Out Of Nothing At All_Rock_Rock Baladas_1983.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Alias_More Than Words Can Say_Rock_Rock Baladas_1990.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Berlin_Take My Breath Away_Rock_Rock Baladas_1986.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Bon Jovi_I'll Be There For You_Rock_Rock Baladas_1988.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Boston_Amanda_Rock_Rock Baladas_1986.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Bryan Adams_Heaven_Rock_Rock Baladas_1984.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Bryan Adams_Straight From The Heart_1983.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Captain and Tennille_Do that to me one more time_Rock_Rock Baladas_1979.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Crowded House_Weather With You_Rock_Rock Baladas_1992.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Deep Purple_Child in Time_Rock_Rock Baladas_1968.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Europe_Carrie_Rock_Rock Baladas_1986.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Paul Young_Every time go you away_Rock_Rock Baladas_1985.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Extreme_More Than Words_Rock_Rock Baladas_1990.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/F.R David_Words_Rock_Rock Baladas_1982.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/Firehouse_When I Look Into Your Eyes_Rock_Rock Baladas_1992.mp3",
    "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock Baladas/
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr).mean()
    chroma = librosa.feature.chroma_stft(y=y, sr=sr).mean()


    return {
        "beats": beats,
        "tempo": tempo,
        "mfcc": mfcc.tolist(),
        "zero_crossing_rate": zcr,
        "rolloff": rolloff,
        "spectral_centroid": spectral_centroid,
        "spectral_bandwidth": spectral_bandwidth,
        "chroma_stft": chroma,
        "rmse_1": rmse_values[0] if len(rmse_values) > 0 else None,
        "rmse_2": rmse_values[1] if len(rmse_values) > 1 else None,
        "rmse_3": rmse_values[2] if len(rmse_values) > 2 else None,
        "rmse_4": rmse_values[3] if len(rmse_values) > 3 else None,
        "rmse_5": rmse_values[4] if len(rmse_values) > 4 else None,
        "rmse_6": rmse_values[5] if len(rmse_values) > 5 else None,
        "rmse_7": rmse_values[6] if len(rmse_values) > 6 else None,
        "rmse_8": rmse_values[7] if len(rmse_values) > 7 else None,
        "rmse_9": rmse_values[8] if len(rmse_values) > 8 else None,
        "rmse_10": rmse_values[9] if len(rmse_values) > 9 else None,
        "rmse_11": rmse_values[10] if len(rmse_values) > 10 else None,
        "rmse_12": rmse_values[11] if len(rmse_values) > 11 else None,
        "rmse_13": rmse_values[12] if len(rmse_values) > 12 else None,
        "rmse_14": rmse_values[13] if len(rmse_values) > 13 else None,
        "rmse_15": rmse_values[14] if len(rmse_values) > 14 else None,
        "rmse_16": rmse_values[15] if len(rmse_values) > 15 else None,
        "rmse_17": rmse_values[16] if len(rmse_values) > 16 else None,
        "rmse_18": rmse_values[17] if len(rmse_values) > 17 else None,
        "rmse_19": rmse_values[18] if len(rmse_values) > 18 else None,
        "rmse_20": rmse_values[19] if len(rmse_values) > 19 else None,    
        
    }

# Lista para almacenar los resultados
datos_audio2 = []

# Procesar cada archivo en la lista
for ruta in rutas_audio2:
    try:
        y, sr = librosa.load(ruta, sr=None)  # Cargar archivo de audio
        caracteristicas = extract_features(y, sr)  # Extraer características
        caracteristicas["file"] = ruta  # Agregar el nombre del archivo
        datos_audio2.append(caracteristicas)  # Guardar los resultados
    except Exception as e:
        print(f"Error procesando {ruta}: {e}")

# Crear un DataFrame con los datos
df_audio2 = pd.DataFrame(datos_audio2)

# Mostrar el DataFrame
print(df_audio2)

# Opcional: Guardar el DataFrame en un archivo CSV
df_audio2.to_csv("caracteristicas_audio2.csv", index=False)

# %%
datos_canciones2 = []

# Procesar cada archivo en la lista
for ruta in rutas_audio2:
    # Obtener solo el nombre del archivo
    archivo = ruta.split('/')[-1]
    # Separar el nombre del archivo en partes (artista, canción, género, subgénero y año)
    partes = archivo.split('_')
    if len(partes) >= 5:  # Asegurarse de que hay al menos tres partes
        artist = partes[0].replace('-', ' ')  # Reemplazar guiones por espacios
        song = partes[1].replace('-', ' ')
        genre = partes[2].replace('-', ' ')  # Quitar la extensión
        subgenre = partes[3].replace('-', ' ')
        year = partes[4].replace('-', ' ').replace('.mp3', '')
        # Añadir los datos como diccionario a la lista
        datos_canciones2.append({
            "artist": artist,
            "song": song,
            "genre": genre,
            "subgenre": subgenre,
            "year": year
        })

# Crear un DataFrame con los datos
df_canciones2 = pd.DataFrame(datos_canciones2)

# Mostrar el DataFrame
print(df_canciones2)

# Opcional: Guardar el DataFrame en un archivo CSV
df_canciones2.to_csv("datos_canciones2.csv", index=False)

# %%
df_canciones2.sample(24)

# %%
df2 = pd.merge(df_canciones2, df_audio2, left_index=True, right_index=True, how='inner')

# %%
df2.to_csv('musica2.csv', index=False)

# %%
columnas_a_formatear = ['rmse_1', 'rmse_2', 'rmse_3', 'rmse_4', 'rmse_5','rmse_6', 'rmse_7', 'rmse_8', 'rmse_9', 'rmse_10', 'rmse_11', 'rmse_12', 'rmse_13', 'rmse_14', 'rmse_15', 
                        'rmse_16', 'rmse_17', 'rmse_18', 'rmse_19', 'rmse_20']

# Verifica si las columnas existen en el DataFrame
columnas_presentes = [col for col in columnas_a_formatear if col in df2.columns]

# Aplicar formato con dos decimales
df2[columnas_presentes] = df2[columnas_presentes].applymap(lambda x: f"{x:.8f}")

# Guardar el archivo con los valores formateados
df2.to_csv('archivo_formateado2.csv', index=False)

# %%
df2.to_csv('archivo_formateado2.csv', index=False)

# %%
df2= pd.read_csv('archivo_formateado2.csv')

# %%
rutas_audio3=  ["/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Rock en Español/Reincidentes_Vicio_Rock_Rock en Español_1994.mp3", 
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Dj-Napo_El-ritmo-ms_Electronica_Techno_1999.mp3", 
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Abel-The-Kid-y-Raul-Ortiz_Electrication_Electronica_Techno_2002.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Abel-the-Kid-y-Raul-Ortiz_Baila_Electronica_Techno_2004.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Alex-Trackone-y-Dj-Napo_La-nube_Electronica_Techno_2000.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Alex-Trackone_Genetiko_Electronica_Techno_2006.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Alex-Trackone-ala-Lawrence-Lock_Technobase_Electronica_Techno_2004.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Ben-Sims_Remanipulator_Electronica_Techno_1998.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Cisco-Ferreira-aka-The-Advent_Kurva_Electronica_Techno_2005.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Danili-Di-Corto_Time-of-passion_Electronica_Techno_2007.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/David-Marshall_Embola_Electronica_Techno_2005.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Digital-Express_The-Club_Electronica_Techno_2004.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Digital-Express-y-Michel-de-Hey_The-club-remix_Electronica_Techno_2002.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Dj Gilbert_Dulux_Electronica_Techno_2000.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Filterheadz_Yimanya_Electronica_Techno_2005.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Jeff Mills_The Bells_Electronica_Techno_1996.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Jeff Mills & Dj Rolando_Jaguar remix_Electronica_Techno_2002.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Julio Posadas_Indhu_Electronica_Techno_2022.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Lithium_Deep jungle_Electronica_Techno_2002.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Mackenzie Feat. Jessy_Arpegia (Without You)_Electronica_Techno_1998.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Mauro Picotto_Bangkok_Electronica_Techno_2005.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Max Walder & Manu Kenton_Bongo Spirit_Electronica_Techno_2007.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Mojado_Fuerte_Electronica_Techno_2007.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Plastikman_Spastik_Electronica_Techno_1993.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Randy Katana_Fancy Fair_Electronica_Techno_2009.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Randy Katana_One solid wave original mix_Electronica_Techno_2003.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Substate_Horizon_Electronica_Techno_2005.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Surgeon_La Real_Electronica_Techno_2000.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Taksi_Schneesturm_Electronica_Techno_2001.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Tekken_Tribal Pursuit_Electronica_Techno_2001.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/The Advent_Inn Balance (Cozmic Spore Remix)_Electronica_Techno_2003.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/The Roc Project feat. Tina Arena_Never Filterheadz remix_Electronica_Techno_2004.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Thomas Krome_Bitches From Hell_Electronica_Techno_2003.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Tim Xavier_Theater Of Sound_Electronica_Techno_2003.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Titanium_Dukun (Marco Bailey Remix)_Electronica_Techno_2003.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Oscar Mulero_Anaconda_Electronica_Techno_2005.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Tom Hafman vs submission_El vacio mix_Electronica_Techno_2003.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Tomaz vs Filterheadz_Lazy people_Electronica_Techno_2002.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Tomaz vs Filterheadz_Sunshine_Electronica_Techno_2002.mp3",
                "/Users/nosolomusica/Desktop/Analisis_de_Datos/Semana8/FINAL_PROYECT/Canciones/Techno/Umek_Soludeks_Electronica_Techno_2000.mp3"]

# %%
def extract_features(y, sr):
    tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
    beats = len(beat_frames)
    rmse = librosa.feature.rms(y=y)
    rmse_values = rmse[0][:20]  # Tomamos los primeros 20 valores de RMSE
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13).mean()
    zcr = librosa.feature.zero_crossing_rate(y).mean()
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr).mean()
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr).mean()
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr).mean()
    chroma = librosa.feature.chroma_stft(y=y, sr=sr).mean()


    return {
        "beats": beats,
        "tempo": tempo,
        "mfcc": mfcc.tolist(),
        "zero_crossing_rate": zcr,
        "rolloff": rolloff,
        "spectral_centroid": spectral_centroid,
        "spectral_bandwidth": spectral_bandwidth,
        "chroma_stft": chroma,
        "rmse_1": rmse_values[0] if len(rmse_values) > 0 else None,
        "rmse_2": rmse_values[1] if len(rmse_values) > 1 else None,
        "rmse_3": rmse_values[2] if len(rmse_values) > 2 else None,
        "rmse_4": rmse_values[3] if len(rmse_values) > 3 else None,
        "rmse_5": rmse_values[4] if len(rmse_values) > 4 else None,
        "rmse_6": rmse_values[5] if len(rmse_values) > 5 else None,
        "rmse_7": rmse_values[6] if len(rmse_values) > 6 else None,
        "rmse_8": rmse_values[7] if len(rmse_values) > 7 else None,
        "rmse_9": rmse_values[8] if len(rmse_values) > 8 else None,
        "rmse_10": rmse_values[9] if len(rmse_values) > 9 else None,
        "rmse_11": rmse_values[10] if len(rmse_values) > 10 else None,
        "rmse_12": rmse_values[11] if len(rmse_values) > 11 else None,
        "rmse_13": rmse_values[12] if len(rmse_values) > 12 else None,
        "rmse_14": rmse_values[13] if len(rmse_values) > 13 else None,
        "rmse_15": rmse_values[14] if len(rmse_values) > 14 else None,
        "rmse_16": rmse_values[15] if len(rmse_values) > 15 else None,
        "rmse_17": rmse_values[16] if len(rmse_values) > 16 else None,
        "rmse_18": rmse_values[17] if len(rmse_values) > 17 else None,
        "rmse_19": rmse_values[18] if len(rmse_values) > 18 else None,
        "rmse_20": rmse_values[19] if len(rmse_values) > 19 else None,    
        
    }

# Lista para almacenar los resultados
datos_audio3 = []

# Procesar cada archivo en la lista
for ruta in rutas_audio3:
    try:
        y, sr = librosa.load(ruta, sr=None)  # Cargar archivo de audio
        caracteristicas = extract_features(y, sr)  # Extraer características
        caracteristicas["file"] = ruta  # Agregar el nombre del archivo
        datos_audio3.append(caracteristicas)  # Guardar los resultados
    except Exception as e:
        print(f"Error procesando {ruta}: {e}")

# Crear un DataFrame con los datos
df_audio3 = pd.DataFrame(datos_audio3)

# Mostrar el DataFrame
print(df_audio3)

# Opcional: Guardar el DataFrame en un archivo CSV
df_audio3.to_csv("caracteristicas_audio3.csv", index=False)

# %%
df_audio3 = pd.read_csv("caracteristicas_audio3.csv")
df_audio3

# %%
datos_canciones3 = []

# Procesar cada archivo en la lista
for ruta in rutas_audio3:
    # Obtener solo el nombre del archivo
    archivo = ruta.split('/')[-1]
    # Separar el nombre del archivo en partes (artista, canción, género, subgénero y año)
    partes = archivo.split('_')
    if len(partes) >= 5:  # Asegurarse de que hay al menos tres partes
        artist = partes[0].replace('-', ' ')  # Reemplazar guiones por espacios
        song = partes[1].replace('-', ' ')
        genre = partes[2].replace('-', ' ')  # Quitar la extensión
        subgenre = partes[3].replace('-', ' ')
        year = partes[4].replace('-', ' ').replace('.mp3', '')
        # Añadir los datos como diccionario a la lista
        datos_canciones3.append({
            "artist": artist,
            "song": song,
            "genre": genre,
            "subgenre": subgenre,
            "year": year
        })

# Crear un DataFrame con los datos
df_canciones3 = pd.DataFrame(datos_canciones3)

# Mostrar el DataFrame
print(df_canciones3)

# Opcional: Guardar el DataFrame en un archivo CSV
df_canciones3.to_csv("datos_canciones3.csv", index=False)

# %%
df_canciones3 = pd.read_csv("datos_canciones3.csv")

# %%
df_canciones3

# %%
df3 = pd.merge(df_canciones3, df_audio3, left_index=True, right_index=True, how='inner')

# %%
df3

# %%
df3.to_csv('musica3.csv', index=False)

# %%
columnas_a_formatear = ['rmse_1', 'rmse_2', 'rmse_3', 'rmse_4', 'rmse_5','rmse_6', 'rmse_7', 'rmse_8', 'rmse_9', 'rmse_10', 'rmse_11', 'rmse_12', 'rmse_13', 'rmse_14', 'rmse_15', 
                        'rmse_16', 'rmse_17', 'rmse_18', 'rmse_19', 'rmse_20']

# Verifica si las columnas existen en el DataFrame
columnas_presentes = [col for col in columnas_a_formatear if col in df3.columns]

# Aplicar formato con dos decimales
df3[columnas_presentes] = df3[columnas_presentes].applymap(lambda x: f"{x:.8f}")

# Guardar el archivo con los valores formateados
df3.to_csv('archivo_formateado3.csv', index=False)

# %%
df3 = pd.read_csv("archivo_formateado4.csv")

# %%
df_concatenado = pd.concat([df, df2, df3], ignore_index=True)

# Guardar el archivo concatenado en un nuevo CSV
df_concatenado.to_csv('archivo_concatenado.csv', index=False)

# %%
df_musica = pd.read_csv('archivo_concatenado.csv')

# %%
df_musica
# Out:
#                         artist                        song        genre  \
# 0                 Reincidentes                       Vicio         Rock
# 1                      Dj Napo                 El ritmo ms  Electronica
# 2    Abel The Kid y Raul Ortiz               Electrication  Electronica
# 3    Abel the Kid y Raul Ortiz                       Baila  Electronica
# 4      Alex Trackone y Dj Napo                     La nube  Electronica
# ..                         ...                         ...          ...
# 142                   Titanium  Dukun (Marco Bailey Remix)  Electronica
# 143               Oscar Mulero                    Anaconda  Electronica
# 144   Tom Hafman vs submission                El vacio mix  Electronica
# 145       Tomaz vs Filterheadz                 Lazy people  Electronica
# 146       Tomaz vs Filterheadz                    Sunshine  Electronica
#
#              subgenre  year  beats           tempo      mfcc  \
# 0    Rock en Español  1994    287    [103.359375]  7.414057
# 1              Techno  1999    918   [143.5546875]  1.350599
# 2              Techno  2002    918  [139.67483108]  0.331615
# 3              Techno  2004    961  [139.67483108]  5.476958
# 4              Techno  2000   1111  [139.67483108]  4.739414
# ..                ...   ...    ...             ...       ...
# 142            Techno  2003    643  [139.67483108] -5.148223
# 143            Techno  2005    946  [139.67483108]  3.087595
# 144            Techno  2003    955  [135.99917763]  5.747701
# 145            Techno  2002   1026  [135.99917763]  8.473179
# 146            Techno  2002    643  [135.99917763]  6.071622
#
#      zero_crossing_rate      rolloff  ...   rmse_12   rmse_13   rmse_14  \
# 0              0.069205  5458.417373  ...  0.048378  0.056530  0.060987
# 1              0.073230  6491.287355  ...  0.000000  0.000000  0.000000
# 2              0.066977  7425.992813  ...  0.000000  0.000000  0.000000
# 3              0.026301  5245.070596  ...  0.000000  0.004922  0.031408
# 4              0.041777  5284.012634  ...  0.000009  0.000138  0.003364
# ..                  ...          ...  ...       ...       ...       ...
# 142            0.039373  6004.217913  ...  0.009527  0.007534  0.004597
# 143            0.109243  8918.494381  ...  0.000000  0.000000  0.000000
# 144            0.086701  7736.011952  ...  0.000008  0.007187  0.008954
# 145            0.054180  6651.333572  ...  0.000033  0.000036  0.000034
# 146            0.051538  5425.724989  ...  0.000013  0.000047  0.001859
#
#       rmse_15   rmse_16   rmse_17   rmse_18   rmse_19   rmse_20  \
# 0    0.061626  0.058362  0.055913  0.052699  0.052933  0.052752
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.000261  0.000298  0.000304  0.000347  0.000304  0.000385
# 3    0.046066  0.112812  0.116601  0.144684  0.162619  0.179323
# 4    0.014328  0.038531  0.052192  0.053312  0.055055  0.060161
# ..        ...       ...       ...       ...       ...       ...
# 142  0.004321  0.003913  0.002949  0.001552  0.001334  0.001281
# 143  0.000000  0.000026  0.020305  0.051187  0.063352  0.068378
# 144  0.015554  0.018085  0.016891  0.017285  0.012988  0.009424
# 145  0.000030  0.000034  0.000036  0.000037  0.000036  0.000030
# 146  0.002044  0.002469  0.002832  0.002341  0.002412  0.002254
#
#                                                   file
# 0    /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 1    /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 2    /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 3    /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 4    /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# ..                                                 ...
# 142  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 143  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 144  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 145  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
# 146  /Users/nosolomusica/Desktop/Analisis_de_Datos/...
#
# [147 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artist              39 non-null     object
#  1   song                39 non-null     object
#  2   genre               39 non-null     object
#  3   subgenre            39 non-null     object
#  4   year                39 non-null     int64
#  5   beats               39 non-null     int64
#  6   tempo               39 non-null     object
#  7   mfcc                39 non-null     float64
#  8   zero_crossing_rate  39 non-null     float64
#  9   rolloff             39 non-null     float64
#  10  spectral_centroid   39 non-null     float64
#  11  spectral_bandwidth  39 non-null     float64
#  12  chroma_stft         39 non-null     float64
#  13  rmse_1              39 non-null     float64
#  14  rmse_2              39 non-null     float64
#  15  rmse_3              39 non-null     float64
#  16  rmse_4              39 non-null     float64
#  17  rmse_5              39 non-null     float64
#  18  rmse_6              39 non-null     float64
#  19  rmse_7              39 non-null     float64
#  20  rmse_8              39 non-null     float64
#  21  rmse_9              39 non-null     float64
#  22  rmse_10             39 non-null     float64
#  23  rmse_11             39 non-null     float64
#  24  rmse_12             39 non-null     float64
#  25  rmse_13             39 non-null     float64
#  26  rmse_14             39 non-null     float64
#  27  rmse_15             39 non-null     float64
#  28  rmse_16             39 non-null     float64
#  29  rmse_17             39 non-null     float64
#  30  rmse_18             39 non-null     float64
#  31  rmse_19             39 non-null     float64
#  32  rmse_20             39 non-null     float64
#  33  file                39 non-null     object
# dtypes: float64(26), int64(2), object(6)
# memory usage: 10.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artist              69 non-null     object
#  1   song                69 non-null     object
#  2   genre               69 non-null     object
#  3   subgenre            69 non-null     object
#  4   year                69 non-null     int64
#  5   beats               69 non-null     int64
#  6   tempo               69 non-null     object
#  7   mfcc                69 non-null     float64
#  8   zero_crossing_rate  69 non-null     float64
#  9   rolloff             69 non-null     float64
#  10  spectral_centroid   69 non-null     float64
#  11  spectral_bandwidth  69 non-null     float64
#  12  chroma_stft         69 non-null     float64
#  13  rmse_1              69 non-null     float64
#  14  rmse_2              69 non-null     float64
#  15  rmse_3              69 non-null     float64
#  16  rmse_4              69 non-null     float64
#  17  rmse_5              69 non-null     float64
#  18  rmse_6              69 non-null     float64
#  19  rmse_7              69 non-null     float64
#  20  rmse_8              69 non-null     float64
#  21  rmse_9              69 non-null     float64
#  22  rmse_10             69 non-null     float64
#  23  rmse_11             69 non-null     float64
#  24  rmse_12             69 non-null     float64
#  25  rmse_13             69 non-null     float64
#  26  rmse_14             69 non-null     float64
#  27  rmse_15             69 non-null     float64
#  28  rmse_16             69 non-null     float64
#  29  rmse_17             69 non-null     float64
#  30  rmse_18             69 non-null     float64
#  31  rmse_19             69 non-null     float64
#  32  rmse_20             69 non-null     float64
#  33  file                69 non-null     object
# dtypes: float64(26), int64(2), object(6)
# memory usage: 18.5+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artist              39 non-null     object
#  1   song                39 non-null     object
#  2   genre               39 non-null     object
#  3   subgenre            39 non-null     object
#  4   year                39 non-null     int64
#  5   beats               39 non-null     int64
#  6   tempo               39 non-null     object
#  7   mfcc                39 non-null     float64
#  8   zero_crossing_rate  39 non-null     float64
#  9   rolloff             39 non-null     float64
#  10  spectral_centroid   39 non-null     float64
#  11  spectral_bandwidth  39 non-null     float64
#  12  chroma_stft         39 non-null     float64
#  13  rmse_1              39 non-null     float64
#  14  rmse_2              39 non-null     float64
#  15  rmse_3              39 non-null     float64
#  16  rmse_4              39 non-null     float64
#  17  rmse_5              39 non-null     float64
#  18  rmse_6              39 non-null     float64
#  19  rmse_7              39 non-null     float64
#  20  rmse_8              39 non-null     float64
#  21  rmse_9              39 non-null     float64
#  22  rmse_10             39 non-null     float64
#  23  rmse_11             39 non-null     float64
#  24  rmse_12             39 non-null     float64
#  25  rmse_13             39 non-null     float64
#  26  rmse_14             39 non-null     float64
#  27  rmse_15             39 non-null     float64
#  28  rmse_16             39 non-null     float64
